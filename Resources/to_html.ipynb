# %%
import pandas as pd
path = "output_data/cities.csv"

# %%
cities = pd.read_csv("../WeatherPy/output_data/cities.csv")
cities
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Bluff -46.6000  168.3333    273.60        87           9
# 1          Kapaa  22.0752 -159.3190    300.14        80          24
# 2      Havøysund  70.9963   24.6622    280.64        89          98
# 3    Tuktoyaktuk  69.4541 -133.0374    289.15        51          40
# 4      Dharampur  20.5333   73.1833    299.61        81          95
# ..           ...      ...       ...       ...       ...         ...
# 524  Fort Nelson  58.8053 -122.7002    294.48        37          56
# 525        Kutum  14.2000   24.6667    303.32        18          27
# 526       Nabire  -3.3667  135.4833    296.87        93          99
# 527       Breţcu  46.0500   26.3000    290.02        99          96
# 528        Caála -12.8525   15.5606    288.45        34          25
#
#      Wind Speed Country        Date  Temperature (F)
# 0          4.06      NZ  1624125440            33.08
# ...

# %%
cities = cities_df.to_html("cities.html")
